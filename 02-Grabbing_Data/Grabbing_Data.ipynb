# %% [markdown]
# ## Grabbing the Data
# -----

# %% [markdown]
# ### Setup:
# ---

# %%
# Import dependencies
from pathlib import Path
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import datetime
from pytz import timezone
import re

# %% [markdown]
# ### Grab NFL Game Data from Past Years:
# ---

# %%
# helper function to pull text from the html element
# if error occurs - return 'N/A'
def getHTMLValue(input, parent=False):
    try:
        if parent:
            return input.parent.text
        else:
            return input.text
    except:
        return 'N/A'

# %%
# helper function to replace text in the results string.
# if error occurs - return the original value
def parseLabels(rawData, throwAway):
    try:
        return rawData.replace(throwAway, '')
    except:
        return rawData

# %%
# get the numerical month from string
def getMonthNumber(month_string):
    if (month_string == "September"):
        return 9
    if (month_string == "October"):
        return 10
    if (month_string == "November"):
        return 11
    if (month_string == "December"):
        return 12
    if (month_string == "January"):
        return 1

# %%
# need to get the pytz timezone
def getTimeZone(raw_timezone):
    if (raw_timezone == 'CDT' or raw_timezone == 'CST'):
        return 'America/Chicago'
    if (raw_timezone == 'EDT' or raw_timezone == 'EST'):
        return 'America/Detroit'
    if (raw_timezone == 'MST' or raw_timezone == 'MDT'):
        return 'America/Denver'
    if (raw_timezone == 'PDT' or raw_timezone == 'PST'):
        return 'America/Los_Angeles'

    # default - return America/Detroit
    return 'America/Detroit'

# %%
# helper function to get standard kickoff time from date and time
def getKickoffTime(year, date, time):
    date_without_year = date.split(',')[0]
    date_parts = date_without_year.split(' ')
    month = getMonthNumber(date_parts[0].strip())
    day = int(date_parts[1])
    if month == 1:
        game_year = year + 1
    else:
        game_year = year
    
    time = time.replace('/', ' ')
    time = time.replace(u'\xa0', u' ')
    time_parts = time.split(' ')
    clock = time_parts[0]
    clock_parts = clock.split(":")
    hour = clock_parts[0]
    minute = clock_parts[1]
    if (time_parts[1] == 'p.m.' and int(hour) < 12):
        hour = int(hour) + 12
    
    if (len(time_parts) > 2):
        time_zone = getTimeZone(time_parts[2])
    else:
        time_zone = getTimeZone('')

    dt  = datetime.datetime(int(game_year),int(month),int(day),int(hour),int(minute))
    fromZone, toZone = timezone(time_zone), timezone('EST')

    standardized_time = fromZone.localize(dt).astimezone(toZone)

    return f'{standardized_time.hour}:{standardized_time.minute:02d}'

# %%
# Set Range of Years
years_list = [2022]
years_list
# Out:
# [2022]

# %%
# Set List of Teams
teams_list = ["Arizona Cardinals",
    "Atlanta Falcons",
    "Baltimore Ravens",
    "Buffalo Bills",
    "Carolina Panthers",
    "Chicago Bears",
    "Cincinnati Bengals",
    "Cleveland Browns",
    "Dallas Cowboys",
    "Denver Broncos",
    "Detroit Lions",
    "Green Bay Packers",
    "Houston Texans",
    "Indianapolis Colts",
    "Jacksonville Jaguars",
    "Kansas City Chiefs",
    "Las Vegas Raiders",
    "Los Angeles Chargers",
    "Los Angeles Rams",
    "Miami Dolphins",
    "Minnesota Vikings",
    "New England Patriots",
    "New Orleans Saints",
    "New York Giants",
    "New York Jets",
    "Philadelphia Eagles",
    "Pittsburgh Steelers",
    "San Francisco 49ers",
    "Seattle Seahawks",
    "Tampa Bay Buccaneers",
    "Tennessee Titans",
    "Washington Commanders",
    ]

# %%
# Try With a Single Year (2022) First
for year in years_list:
    for team in teams_list:
        team_format = team.replace(' ', '_')
        url = f'https://en.wikipedia.org/wiki/{year}_{team_format}_season'

        wiki_tables = pd.read_html(url, match='Opponent')

        for table in wiki_tables:
            # if the table has more than 5 rows, that's our results table
            if (len(table) > 5):
                results_df = table

        results_df['team'] = team
        results_df['weather_condition'] = ''
        results_df['temp_f'] = ''
        results_df['time'] = ''
        results_df['city'] = ''
        results_df['state'] = ''
        results_df['year'] = year

        # screen scrape the game data to get the weather, time, and location
        team_response = requests.get(url)
        team_response_html = team_response.content.decode('utf-8')
        team_response_parsed = BeautifulSoup(team_response_html)

        uls = team_response_parsed.find_all('b', string="Date")
        for ul in uls:
            game_date = parseLabels(getHTMLValue(ul.parent), 'Date: ')
            if len(results_df.loc[results_df['Date'] == game_date]) > 0:
                print(team, game_date)
                game_weather = parseLabels(getHTMLValue(ul.parent.parent.find('b', string="Game weather"), parent=True), 'Game weather: ').replace(u'\xa0', u' ')
                
                temp_f = ''
                degrees = game_weather
                weather_without_temp = re.split("\d{1,2} °F", game_weather)
                
                for element in weather_without_temp:
                    degrees = degrees.replace(element, '')

                temp_f = degrees.replace('°F', '').strip()
                conditions = weather_without_temp[0].replace(',', '').strip()
                
                if (temp_f == ''):
                    temp_f = 72

                game_time = parseLabels(getHTMLValue(ul.parent.parent.find('b', string="Game time"), parent=True), 'Game time: ')
                game_location = parseLabels(getHTMLValue(ul.parent.parent.parent.find('p')), 'at ').replace('\n', '')

                game_location_parts = game_location.split(',')
                results_df.loc[results_df['Date'] == game_date, 'weather_condition'] = conditions
                results_df.loc[results_df['Date'] == game_date, 'temp_f'] = int(temp_f)
                results_df.loc[results_df['Date'] == game_date, 'time'] = getKickoffTime(year, game_date, game_time)
                results_df.loc[results_df['Date'] == game_date, 'city'] = game_location_parts[1].strip()
                results_df.loc[results_df['Date'] == game_date, 'state'] = game_location_parts[2].strip()

        # export to csv here - by year and team
        results_df.to_csv(f'../03-Wrangling_Data/Grabbing_Data_Exports/{year}_{team_format}.csv')
# Out:
# Arizona Cardinals September 11
# Arizona Cardinals September 18
# Arizona Cardinals September 25
# Arizona Cardinals October 2
# Arizona Cardinals October 9
# Arizona Cardinals October 16
# Arizona Cardinals October 20
# Arizona Cardinals October 30
# Arizona Cardinals November 6
# Arizona Cardinals November 13
# Arizona Cardinals November 21
# Arizona Cardinals November 27
# Arizona Cardinals December 12
# Arizona Cardinals December 18
# Arizona Cardinals December 25
# Arizona Cardinals January 1
# Arizona Cardinals January 8
# Atlanta Falcons September 11
# Atlanta Falcons September 18
# Atlanta Falcons September 25
# Atlanta Falcons October 2
# Atlanta Falcons October 9
# Atlanta Falcons October 16
# Atlanta Falcons October 23
# Atlanta Falcons October 30
# Atlanta Falcons November 6
# Atlanta Falcons November 10
# Atlanta Falcons November 20
# Atlanta Falcons November 27
# Atlanta Falcons December 4
# Atlanta Falcons December 18
# Atlanta Falcons December 24
# Atlanta Falcons January 1
# Atlanta Falcons January 8
# Baltimore Ravens September 11
# Baltimore Ravens September 18
# Baltimore Ravens September 25
# Baltimore Ravens October 2
# Baltimore Ravens October 9
# Baltimore Ravens October 16
# Baltimore Ravens October 23
# Baltimore Ravens October 27
# Baltimore Ravens November 7
# Baltimore Ravens November 20
# Baltimore Ravens November 27
# Baltimore Ravens December 4
# Baltimore Ravens December 11
# Baltimore Ravens December 17
# Baltimore Ravens December 24
# Baltimore Ravens January 1
# Baltimore Ravens January 8
# Buffalo Bills September 8
# Buffalo Bills September 19
# Buffalo Bills September 25
# Buffalo Bills October 2
# Buffalo Bills October 9
# Buffalo Bills October 16
# Buffalo Bills October 30
# Buffalo Bills November 6
# Buffalo Bills November 13
# Buffalo Bills November 20
# Buffalo Bills November 24
# Buffalo Bills December 1
# Buffalo Bills December 11
# Buffalo Bills December 17
# Buffalo Bills December 24
# Buffalo Bills January 8
# Carolina Panthers September 11
# Carolina Panthers September 18
# Carolina Panthers September 25
# Carolina Panthers October 2
# Carolina Panthers October 9
# Carolina Panthers October 16
# Carolina Panthers October 23
# Carolina Panthers October 30
# Carolina Panthers November 6
# Carolina Panthers November 10
# Carolina Panthers November 20
# Carolina Panthers November 27
# Carolina Panthers December 11
# Carolina Panthers December 18
# Carolina Panthers December 24
# Carolina Panthers January 1
# Carolina Panthers January 8
# Chicago Bears September 11
# Chicago Bears September 18
# Chicago Bears September 25
# Chicago Bears October 2
# Chicago Bears October 9
# Chicago Bears October 13
# Chicago Bears October 24
# Chicago Bears October 30
# Chicago Bears November 6
# Chicago Bears November 13
# Chicago Bears November 20
# Chicago Bears November 27
# Chicago Bears December 4
# Chicago Bears December 18
# Chicago Bears December 24
# Chicago Bears January 1
# Chicago Bears January 8
# Cincinnati Bengals September 11
# Cincinnati Bengals September 18
# Cincinnati Bengals September 25
# Cincinnati Bengals September 29
# Cincinnati Bengals October 9
# Cincinnati Bengals October 16
# Cincinnati Bengals October 23
# Cincinnati Bengals October 31
# Cincinnati Bengals November 6
# Cincinnati Bengals November 20
# Cincinnati Bengals November 27
# Cincinnati Bengals December 4
# Cincinnati Bengals December 11
# Cincinnati Bengals December 18
# Cincinnati Bengals December 24
# Cincinnati Bengals January 8
# Cleveland Browns September 11
# Cleveland Browns September 18
# Cleveland Browns September 22
# Cleveland Browns October 2
# Cleveland Browns October 9
# Cleveland Browns October 16
# Cleveland Browns October 23
# Cleveland Browns October 31
# Cleveland Browns November 13
# Cleveland Browns November 20
# Cleveland Browns November 27
# Cleveland Browns December 4
# Cleveland Browns December 11
# Cleveland Browns December 17
# Cleveland Browns December 24
# Cleveland Browns January 1
# Cleveland Browns January 8
# Dallas Cowboys September 11
# Dallas Cowboys September 18
# Dallas Cowboys September 26
# Dallas Cowboys October 2
# Dallas Cowboys October 9
# Dallas Cowboys October 16
# Dallas Cowboys October 23
# Dallas Cowboys October 30
# Dallas Cowboys November 13
# Dallas Cowboys November 20
# Dallas Cowboys November 24
# Dallas Cowboys December 4
# Dallas Cowboys December 11
# Dallas Cowboys December 18
# Dallas Cowboys December 24
# Dallas Cowboys December 29
# Dallas Cowboys January 8
# Denver Broncos September 12
# Denver Broncos September 18
# Denver Broncos September 25
# Denver Broncos October 2
# Denver Broncos October 6
# Denver Broncos October 17
# Denver Broncos October 23
# Denver Broncos October 30
# Denver Broncos November 13
# Denver Broncos November 20
# Denver Broncos November 27
# Denver Broncos December 4
# Denver Broncos December 11
# Denver Broncos December 18
# Denver Broncos December 25
# Denver Broncos January 8
# Detroit Lions September 11
# Detroit Lions September 18
# Detroit Lions September 25
# Detroit Lions October 2
# Detroit Lions October 9
# Detroit Lions October 23
# Detroit Lions October 30
# Detroit Lions November 6
# Detroit Lions November 13
# Detroit Lions November 20
# Detroit Lions November 24
# Detroit Lions December 4
# Detroit Lions December 11
# Detroit Lions December 18
# Detroit Lions December 24
# Detroit Lions January 1
# Detroit Lions January 8
# Green Bay Packers September 11
# Green Bay Packers September 18
# Green Bay Packers September 25
# Green Bay Packers October 2
# Green Bay Packers October 9
# Green Bay Packers October 16
# Green Bay Packers October 23
# Green Bay Packers October 30
# Green Bay Packers November 6
# Green Bay Packers November 13
# Green Bay Packers November 17
# Green Bay Packers November 27
# Green Bay Packers December 4
# Green Bay Packers December 19
# Green Bay Packers December 25
# Houston Texans September 11
# Houston Texans September 18
# Houston Texans September 25
# Houston Texans October 2
# Houston Texans October 9
# Houston Texans October 23
# Houston Texans October 30
# Houston Texans November 3
# Houston Texans November 13
# Houston Texans November 20
# Houston Texans November 27
# Houston Texans December 4
# Houston Texans December 11
# Houston Texans December 18
# Houston Texans December 24
# Houston Texans January 1
# Houston Texans January 8
# Indianapolis Colts September 11
# Indianapolis Colts September 18
# Indianapolis Colts September 25
# Indianapolis Colts October 2
# Indianapolis Colts October 6
# Indianapolis Colts October 16
# Indianapolis Colts October 23
# Indianapolis Colts October 30
# Indianapolis Colts November 6
# Indianapolis Colts November 13
# Indianapolis Colts November 20
# Indianapolis Colts November 28
# Indianapolis Colts December 4
# Indianapolis Colts December 17
# Indianapolis Colts December 26
# Indianapolis Colts January 1
# Indianapolis Colts January 8
# Jacksonville Jaguars September 11
# Jacksonville Jaguars September 18
# Jacksonville Jaguars September 25
# Jacksonville Jaguars October 2
# Jacksonville Jaguars October 9
# Jacksonville Jaguars October 16
# Jacksonville Jaguars October 23
# Jacksonville Jaguars October 30
# Jacksonville Jaguars November 6
# Jacksonville Jaguars November 13
# Jacksonville Jaguars November 27
# Jacksonville Jaguars December 4
# Jacksonville Jaguars December 11
# Jacksonville Jaguars December 18
# Jacksonville Jaguars December 22
# Jacksonville Jaguars January 1
# Jacksonville Jaguars January 7
# Kansas City Chiefs September 11
# Kansas City Chiefs September 15
# Kansas City Chiefs September 25
# Kansas City Chiefs October 2
# Kansas City Chiefs October 10
# Kansas City Chiefs October 16
# Kansas City Chiefs October 23
# Kansas City Chiefs November 6
# Kansas City Chiefs November 13
# Kansas City Chiefs November 20
# Kansas City Chiefs November 27
# Kansas City Chiefs December 4
# Kansas City Chiefs December 11
# Kansas City Chiefs December 18
# Kansas City Chiefs December 24
# Kansas City Chiefs January 1
# Kansas City Chiefs January 7
# Las Vegas Raiders September 11
# Las Vegas Raiders September 18
# Las Vegas Raiders September 25
# Las Vegas Raiders October 2
# Las Vegas Raiders October 10
# Las Vegas Raiders October 23
# Las Vegas Raiders October 30
# Las Vegas Raiders November 6
# Las Vegas Raiders November 13
# Las Vegas Raiders November 20
# Las Vegas Raiders November 27
# Las Vegas Raiders December 4
# Las Vegas Raiders December 8
# Las Vegas Raiders December 18
# Las Vegas Raiders December 24
# Las Vegas Raiders January 1
# Las Vegas Raiders January 7
# Los Angeles Chargers September 11
# Los Angeles Chargers September 15
# Los Angeles Chargers September 25
# Los Angeles Chargers October 2
# Los Angeles Chargers October 9
# Los Angeles Chargers October 17
# Los Angeles Chargers October 23
# Los Angeles Chargers November 6
# Los Angeles Chargers November 13
# Los Angeles Chargers November 20
# Los Angeles Chargers November 27
# Los Angeles Chargers December 4
# Los Angeles Chargers December 11
# Los Angeles Chargers December 18
# Los Angeles Chargers December 26
# Los Angeles Chargers January 1
# Los Angeles Chargers January 8
# Los Angeles Rams September 8
# Los Angeles Rams September 18
# Los Angeles Rams September 25
# Los Angeles Rams October 3
# Los Angeles Rams October 9
# Los Angeles Rams October 16
# Los Angeles Rams October 30
# Los Angeles Rams November 6
# Los Angeles Rams November 13
# Los Angeles Rams November 20
# Los Angeles Rams November 27
# Los Angeles Rams December 4
# Los Angeles Rams December 8
# Los Angeles Rams December 19
# Los Angeles Rams December 25
# Los Angeles Rams January 1
# Los Angeles Rams January 8
# Miami Dolphins September 11
# Miami Dolphins September 18
# Miami Dolphins September 25
# Miami Dolphins September 29
# Miami Dolphins October 9
# Miami Dolphins October 16
# Miami Dolphins October 23
# Miami Dolphins October 30
# Miami Dolphins November 6
# Miami Dolphins November 13
# Miami Dolphins November 27
# Miami Dolphins December 4
# Miami Dolphins December 11
# Miami Dolphins December 17
# Miami Dolphins December 25
# Miami Dolphins January 1
# Miami Dolphins January 8
# Minnesota Vikings September 11
# Minnesota Vikings September 19
# Minnesota Vikings September 25
# Minnesota Vikings October 2
# Minnesota Vikings October 9
# Minnesota Vikings October 16
# Minnesota Vikings October 30
# Minnesota Vikings November 6
# Minnesota Vikings November 13
# Minnesota Vikings November 20
# Minnesota Vikings November 24
# Minnesota Vikings December 4
# Minnesota Vikings December 11
# Minnesota Vikings December 17
# Minnesota Vikings December 24
# Minnesota Vikings January 1
# Minnesota Vikings January 8
# New England Patriots September 11
# New England Patriots September 18
# New England Patriots September 25
# New England Patriots October 2
# New England Patriots October 9
# New England Patriots October 16
# New England Patriots October 24
# New England Patriots October 30
# New England Patriots November 6
# New England Patriots November 20
# New England Patriots November 24
# New England Patriots December 1
# New England Patriots December 12
# New England Patriots December 18
# New England Patriots December 24
# New England Patriots January 1
# New England Patriots January 8
# New Orleans Saints September 11
# New Orleans Saints September 18
# New Orleans Saints September 25
# New Orleans Saints October 2
# New Orleans Saints October 9
# New Orleans Saints October 16
# New Orleans Saints October 20
# New Orleans Saints October 30
# New Orleans Saints November 7
# New Orleans Saints November 13
# New Orleans Saints November 20
# New Orleans Saints November 27
# New Orleans Saints December 5
# New Orleans Saints December 18
# New Orleans Saints December 24
# New Orleans Saints January 1
# New Orleans Saints January 8
# New York Giants September 11
# New York Giants September 18
# New York Giants September 26
# New York Giants October 2
# New York Giants October 9
# New York Giants October 16
# New York Giants October 23
# New York Giants October 30
# New York Giants November 13
# New York Giants November 20
# New York Giants November 24
# New York Giants December 4
# New York Giants December 11
# New York Giants December 18
# New York Giants December 24
# New York Giants January 1
# New York Giants January 8
# New York Jets September 11
# New York Jets September 18
# New York Jets September 25
# New York Jets October 2
# New York Jets October 9
# New York Jets October 16
# New York Jets October 23
# New York Jets October 30
# New York Jets November 6
# New York Jets November 20
# New York Jets November 27
# New York Jets December 4
# New York Jets December 11
# New York Jets December 18
# New York Jets December 22
# New York Jets January 1
# New York Jets January 8
# Philadelphia Eagles September 11
# Philadelphia Eagles September 19
# Philadelphia Eagles September 25
# Philadelphia Eagles October 2
# Philadelphia Eagles October 9
# Philadelphia Eagles October 16
# Philadelphia Eagles October 30
# Philadelphia Eagles November 3
# Philadelphia Eagles November 14
# Philadelphia Eagles November 20
# Philadelphia Eagles November 27
# Philadelphia Eagles December 4
# Philadelphia Eagles December 11
# Philadelphia Eagles December 18
# Philadelphia Eagles December 24
# Philadelphia Eagles January 1
# Philadelphia Eagles January 8
# Pittsburgh Steelers September 11
# Pittsburgh Steelers September 18
# Pittsburgh Steelers September 22
# Pittsburgh Steelers October 2
# Pittsburgh Steelers October 9
# Pittsburgh Steelers October 16
# Pittsburgh Steelers October 23
# Pittsburgh Steelers October 30
# Pittsburgh Steelers November 13
# Pittsburgh Steelers November 20
# Pittsburgh Steelers November 28
# Pittsburgh Steelers December 4
# Pittsburgh Steelers December 11
# Pittsburgh Steelers December 18
# Pittsburgh Steelers December 24
# Pittsburgh Steelers January 1
# Pittsburgh Steelers January 8
# San Francisco 49ers September 11
# San Francisco 49ers September 18
# San Francisco 49ers September 25
# San Francisco 49ers October 3
# San Francisco 49ers October 9
# San Francisco 49ers October 16
# San Francisco 49ers October 23
# San Francisco 49ers October 30
# San Francisco 49ers November 13
# San Francisco 49ers November 21
# San Francisco 49ers November 27
# San Francisco 49ers December 4
# San Francisco 49ers December 11
# San Francisco 49ers December 15
# San Francisco 49ers December 24
# Seattle Seahawks September 12
# Seattle Seahawks September 18
# Seattle Seahawks September 25
# Seattle Seahawks October 2
# Seattle Seahawks October 9
# Seattle Seahawks October 16
# Seattle Seahawks October 23
# Seattle Seahawks October 30
# Seattle Seahawks November 6
# Seattle Seahawks November 13
# Seattle Seahawks November 27
# Seattle Seahawks December 4
# Seattle Seahawks December 11
# Seattle Seahawks December 15
# Seattle Seahawks December 24
# Tampa Bay Buccaneers September 11
# Tampa Bay Buccaneers September 18
# Tampa Bay Buccaneers September 25
# Tampa Bay Buccaneers October 2
# Tampa Bay Buccaneers October 9
# Tampa Bay Buccaneers October 16
# Tampa Bay Buccaneers October 23
# Tampa Bay Buccaneers October 27
# Tampa Bay Buccaneers November 6
# Tampa Bay Buccaneers November 13
# Tampa Bay Buccaneers November 27
# Tampa Bay Buccaneers December 5
# Tampa Bay Buccaneers December 11
# Tampa Bay Buccaneers December 18
# Tampa Bay Buccaneers December 25
# Tampa Bay Buccaneers January 1
# Tampa Bay Buccaneers January 8
# Tennessee Titans September 11
# Tennessee Titans September 19
# Tennessee Titans September 25
# Tennessee Titans October 2
# Tennessee Titans October 9
# Tennessee Titans October 23
# Tennessee Titans October 30
# Tennessee Titans November 6
# Tennessee Titans November 13
# Tennessee Titans November 17
# Tennessee Titans November 27
# Tennessee Titans December 4
# Tennessee Titans December 11
# Tennessee Titans December 18
# Tennessee Titans December 24
# Tennessee Titans December 29
# Tennessee Titans January 7
# Washington Commanders September 11
# Washington Commanders September 18
# Washington Commanders September 25
# Washington Commanders October 2
# Washington Commanders October 9
# Washington Commanders October 13
# Washington Commanders October 23
# Washington Commanders October 30
# Washington Commanders November 6
# Washington Commanders November 14
# Washington Commanders November 20
# Washington Commanders November 27
# Washington Commanders December 4
# Washington Commanders December 18
# Washington Commanders December 24
# Washington Commanders January 1
# Washington Commanders January 8

# %% [markdown]
# ### Export Past Game Data as CSV Files:
# ---

# %%
# Export CSV's for Each Team to ../03-Wrangling_Data/Grabbing_Data_Exports
