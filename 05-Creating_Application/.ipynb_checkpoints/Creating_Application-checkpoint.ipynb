# %% [markdown]
# ## Creating the Application
# -----

# %% [markdown]
# ### Setup:
# ---

# %%
# Import dependencies
from pathlib import Path
import pandas as pd

# %% [markdown]
# ### Creating Reference Data CSVs for Columns
# ---

# %%
# Import the Combined Data from /Wrangling_Data_Exports
wrangled_df = pd.read_csv("../04-Building_Model/Wrangling_Data_Exports/Wrangled_Data.csv")

# Display Dataframe
wrangled_df.head()
# Out:
#    Unnamed: 0    Year      Month  Day Time (EST)  Season Week  \
# 0           0  2022.0  September   25      14:25          3.0
# 1           1  2022.0  September   25      14:25          3.0
# 2           2  2022.0   November    6      16:05          9.0
# 3           3  2022.0   November    6      16:05          9.0
# 4           4  2022.0   November   27      16:05         12.0
#
#                 Venue      City    State               Weather Condition  ...  \
# 0  State Farm Stadium  Glendale  Arizona  None (retractable roof closed)  ...
# 1  State Farm Stadium  Glendale  Arizona  None (retractable roof closed)  ...
# 2  State Farm Stadium  Glendale  Arizona                           Sunny  ...
# 3  State Farm Stadium  Glendale  Arizona                           Sunny  ...
# 4  State Farm Stadium  Glendale  Arizona  None (retractable roof closed)  ...
#
#    Home Team Pre-Game Season W/L Ratio  \
# 0                                 0.50
# 1                                 0.50
# 2                                 0.38
# 3                                 0.38
# 4                                 0.36
#
#   Home Team Pre-Game Season Avg Points For  \
# 0                                    25.00
# 1                                    25.00
# 2                                    22.75
# 3                                    22.75
# 4                                    21.82
#
#    Home Team Pre-Game Season Avg Points Against  Outcome  \
# 0                                         33.50      2.0
# 1                                         33.50      2.0
# 2                                         26.25      2.0
# 3                                         26.25      2.0
# 4                                         26.91      2.0
#
#               Away Team  Away Team Pre-Game Season W Streak  \
# 0      Los Angeles Rams                                 1.0
# 1      Los Angeles Rams                                 1.0
# 2      Seattle Seahawks                                 3.0
# 3      Seattle Seahawks                                 3.0
# 4  Los Angeles Chargers                                 0.0
#
#    Away Team Pre-Game Season L Streak  Away Team Pre-Game Season W/L Ratio  \
# 0                                 0.0                                 0.50
# 1                                 0.0                                 0.50
# 2                                 0.0                                 0.62
# 3                                 0.0                                 0.62
# 4                                 2.0                                 0.50
#
#   Away Team Pre-Game Season Avg Points For  \
# 0                                    20.50
# 1                                    20.50
# 2                                    26.25
# 3                                    26.25
# 4                                    22.70
#
#    Away Team Pre-Game Season Avg Points Against
# 0                                         29.00
# 1                                         29.00
# 2                                         24.88
# 3                                         24.88
# 4                                         25.80
#
# [5 rows x 24 columns]

# %%
# Create Aplphabetical Dataframes For Columns (Months, Times, Venues, Cities, States, Weather Conditions, Teams)

# %%
# Create Dataframe for Cities

cities_list = wrangled_df["City"].unique()

# Create Dataframe of Unique Values
cities_df = pd.DataFrame(cities_list)

# Rename Column
cities_df=cities_df.rename(columns={0:"Cities"})

# Sort Alphabetically
cities_df = cities_df.sort_values("Cities", ascending=True)

# Reset Index
cities_df = cities_df.reset_index(drop=True)

# Export New Dataframe
cities_df.to_csv("Reference_Data/Cities_Data.csv")

# Display New Dataframe
cities_df
# Out:
#              Cities
# 0         Arlington
# 1           Atlanta
# 2         Baltimore
# 3         Charlotte
# 4           Chicago
# 5        Cincinnati
# 6         Cleveland
# 7            Denver
# 8           Detroit
# 9   East Rutherford
# 10       Foxborough
# 11         Glendale
# 12        Green Bay
# 13          Houston
# 14     Indianapolis
# 15        Inglewood
# 16     Jacksonville
# 17      Kansas City
# 18         Landover
# 19           London
# 20    Miami Gardens
# 21      Minneapolis
# 22           Munich
# 23        Nashville
# 24      New Orleans
# 25     Orchard Park
# 26         Paradise
# 27     Philadelphia
# 28       Pittsburgh
# 29          Seattle
# 30            Tampa

# %%
# Create Dataframe for Months

cities_list = wrangled_df["City"].unique()

# Create Dataframe of Unique Values
cities_df = pd.DataFrame(cities_list)

# Rename Column
cities_df=cities_df.rename(columns={0:"Cities"})

# Sort Alphabetically
cities_df = cities_df.sort_values("Cities", ascending=True)

# Reset Index
cities_df = cities_df.reset_index(drop=True)

# Export New Dataframe
cities_df.to_csv("Reference_Data/Cities_Data.csv")

# Display New Dataframe
cities_df

# %% [markdown]
# ### Create App:
# ---

# %%
# Import Our Trained Model from /Building_Model_Exports

# %% [markdown]
# ### Get Imputs from User:
# ---

# %% [markdown]
# ### Make Prediction:
# ---

# %% [markdown]
# ### Display Prediction:
# ---

# %% [markdown]
# ### Convert the Preceding Code Into an App.py File:
# ---

# %%
# Copy Code and Move to ../06-Completed_App/App.py
